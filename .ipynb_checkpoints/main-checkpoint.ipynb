# %%
import pandas as pd

df = pd.read_excel('/Users/saikiranpennam/Documents/RA/Western_Sugar_AI_Assessment_Working/2022/Data/SCB_Beetandling_Data.xlsx')

# %%
df.head(50)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2             Tag Name
# 0          NaN         NaN         NaN                Descr  \
# 1          NaN         NaN         NaN                Units
# 2          NaN         NaN         NaN             Plot Min
# 3          NaN         NaN         NaN             Plot Max
# 4          NaN         NaN         NaN           Filter Min
# 5          NaN         NaN         NaN           Filter Max
# 6          NaN         NaN         NaN             Excl Row
# 7          NaN         NaN         NaN          Interpolate
# 8          NaN         NaN         NaN             Decimals
# 9          NaN         NaN         NaN           Time Delay
# 10         NaN         NaN         NaN                Count
# 11         NaN         NaN         NaN                  Avg
# 12         NaN         NaN         NaN                   SD
# 13         NaN         NaN         NaN                  Min
# 14         NaN         NaN         NaN                  Max
# 15         NaN         NaN         NaN       Test Data/Calc
# 16         NaN         NaN         NaN                 6862
# 17         NaN         NaN         NaN  2022-11-01 00:00:00
# 18         NaN         NaN         NaN  2022-11-01 00:15:00
# 19         NaN         NaN         NaN  2022-11-01 00:30:00
# 20         NaN         NaN         NaN  2022-11-01 00:45:00
# 21         NaN         NaN         NaN  2022-11-01 01:00:00
# 22         NaN         NaN         NaN  2022-11-01 01:15:00
# 23         NaN         NaN         NaN  2022-11-01 01:30:00
# 24         NaN         NaN         NaN  2022-11-01 01:45:00
# 25         NaN         NaN         NaN  2022-11-01 02:00:00
# 26         NaN         NaN         NaN  2022-11-01 02:15:00
# 27         NaN         NaN         NaN  2022-11-01 02:30:00
# 28         NaN         NaN         NaN  2022-11-01 02:45:00
# 29         NaN         NaN         NaN  2022-11-01 03:00:00
# 30         NaN         NaN         NaN  2022-11-01 03:15:00
# 31         NaN         NaN         NaN  2022-11-01 03:30:00
# 32         NaN         NaN         NaN  2022-11-01 03:45:00
# 33         NaN         NaN         NaN  2022-11-01 04:00:00
# 34         NaN         NaN         NaN  2022-11-01 04:15:00
# 35         NaN         NaN         NaN  2022-11-01 04:30:00
# 36         NaN         NaN         NaN  2022-11-01 04:45:00
# 37         NaN         NaN         NaN  2022-11-01 05:00:00
# 38         NaN         NaN         NaN  2022-11-01 05:15:00
# 39         NaN         NaN         NaN  2022-11-01 05:30:00
# 40         NaN         NaN         NaN  2022-11-01 05:45:00
# 41         NaN         NaN         NaN  2022-11-01 06:00:00
# 42         NaN         NaN         NaN  2022-11-01 06:15:00
# 43         NaN         NaN         NaN  2022-11-01 06:30:00
# 44         NaN         NaN         NaN  2022-11-01 06:45:00
# 45         NaN         NaN         NaN  2022-11-01 07:00:00
# 46         NaN         NaN         NaN  2022-11-01 07:15:00
# 47         NaN         NaN         NaN  2022-11-01 07:30:00
# 48         NaN         NaN         NaN  2022-11-01 07:45:00
# 49         NaN         NaN         NaN  2022-11-01 08:00:00
#
#    Scottsbluff Factory.KEPWARE.Program:A12_DR_MEAS.WT1201.Val/PLOT
# 0                                    Dirty Beet Scale               \
# 1                                                T/hr
# 2                                                   0
# 3                                                 500
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                             TimeAvg
# 8                                                   2
# 9                                                   0
# 10                                               6862
# 11                                         298.727298
# 12                                         110.935243
# 13                                          -1.792251
# 14                                         575.521113
# 15                                                NaN
# 16                                                NaN
# 17                                         207.046703
# 18                                         201.440789
# 19                                         201.851792
# 20                                         194.654034
# 21                                          197.31388
# 22                                         195.138613
# 23                                         225.422243
# 24                                         264.607173
# 25                                         264.242898
# 26                                         252.922698
# 27                                          202.46005
# 28                                         239.144716
# 29                                         244.450888
# 30                                         250.077046
# 31                                          245.56797
# 32                                         244.472725
# 33                                         247.747752
# 34                                         247.475404
# 35                                         248.737922
# 36                                         243.128553
# 37                                         247.769415
# 38                                         244.838468
# 39                                         280.575272
# 40                                         255.088479
# 41                                         230.682099
# 42                                         346.335692
# 43                                         339.192705
# 44                                         291.015849
# 45                                         300.178736
# 46                                         359.446747
# 47                                         370.517926
# 48                                         366.134028
# 49                                         354.201284
#
#    Scottsbluff Factory.KEPWARE.FT1205/PLOT
# 0                         Flume Water Flow  \
# 1                                      GPM
# 2                                        0
# 3                                     5000
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                  TimeAvg
# 8                                        2
# 9                                        0
# 10                                    6862
# 11                             2005.754784
# 12                              777.016837
# 13                                    T/hr
# 14                             5570.462117
# 15                                     NaN
# 16                                     NaN
# 17                             1523.082898
# 18                              1521.41544
# 19                             1518.747017
# 20                             1499.718798
# 21                             1413.060983
# 22                             1417.734382
# 23                             1436.529496
# 24                             1416.030815
# 25                             1434.679602
# 26                             1419.331633
# 27                             1430.888168
# 28                             1402.535359
# 29                             1418.433495
# 30                             1423.214045
# 31                             1481.740051
# 32                             1571.077854
# 33                             1742.549014
# 34                             1723.661979
# 35                             1708.205778
# 36                             1670.863439
# 37                             1642.207648
# 38                              1558.95135
# 39                             1487.912095
# 40                             1494.068477
# 41                             1515.134457
# 42                             1517.943817
# 43                             1508.315146
# 44                             1675.982939
# 45                             1685.824864
# 46                             1690.400336
# 47                             1738.212513
# 48                             2085.937919
# 49                             2105.030192
#
#    Scottsbluff Factory.KEPWARE.FT1206/PLOT
# 0           Flume Water Recirculation Flow  \
# 1                                      GPM
# 2                                        0
# 3                                     5000
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                  TimeAvg
# 8                                        2
# 9                                        0
# 10                                    6862
# 11                             3342.655744
# 12                             1018.475668
# 13                                3.017314
# 14                             6886.899051
# 15                                     NaN
# 16                                     NaN
# 17                             4089.951859
# 18                             4013.366442
# 19                             4084.815351
# 20                             4110.266287
# 21                              4094.27441
# 22                               4126.0549
# 23                             4120.153496
# 24                             4090.206369
# 25                             4098.173422
# 26                             4082.664848
# 27                             4038.808912
# 28                             4076.126838
# 29                             4083.184587
# 30                             4090.092851
# 31                             4098.558991
# 32                             4087.628348
# 33                             4090.962053
# 34                             4066.751806
# 35                             4067.597289
# 36                             4105.531632
# 37                              4086.50261
# 38                             4086.812492
# 39                             4115.618243
# 40                             4074.408653
# 41                             4079.869929
# 42                             4106.307583
# 43                              4110.38286
# 44                              4121.07871
# 45                             4097.113572
# 46                             4115.269503
# 47                             4033.024202
# 48                             4084.824677
# 49                             4079.685577
#
#    Scottsbluff Factory.KEPWARE.Program:A12_JWRT_MEAS.PT1201.Val/PLOT
# 0                                       JWRT Pressure                 \
# 1                                                PSIG
# 2                                                   0
# 3                                                 150
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                             TimeAvg
# 8                                                   2
# 9                                                   0
# 10                                               6862
# 11                                          68.095628
# 12                                          19.181275
# 13                                          -0.922115
# 14                                         155.459335
# 15                                                NaN
# 16                                                NaN
# 17                                          71.869034
# 18                                          71.439815
# 19                                          71.567319
# 20                                          71.479829
# 21                                            71.4033
# 22                                          71.512524
# 23                                          71.398357
# 24                                          71.353967
# 25                                          71.423856
# 26                                          71.400347
# 27                                          71.284425
# 28                                           71.23965
# 29                                          71.114203
# 30                                          71.119309
# 31                                          71.168445
# 32                                           71.26267
# 33                                          71.357733
# 34                                          71.254236
# 35                                          70.985951
# 36                                           70.94944
# 37                                          71.086086
# 38                                          70.862307
# 39                                          70.540143
# 40                                          70.373306
# 41                                          70.336546
# 42                                          69.863766
# 43                                           69.56393
# 44                                            70.0501
# 45                                          70.364863
# 46                                          70.654022
# 47                                          70.769373
# 48                                          71.094262
# 49                                          71.011482
#
#    Scottsbluff Factory.KEPWARE.CLAR_LI1225/PLOT
# 0                              CLARIFIER LEVEL   \
# 1                                             %
# 2                                             0
# 3                                           100
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                    96.673845
# 12                                     15.61532
# 13                                       0.2783
# 14                                   105.124634
# 15                                          NaN
# 16                                          NaN
# 17                                   102.791712
# 18                                   103.485491
# 19                                   103.622652
# 20                                    103.56744
# 21                                   103.452863
# 22                                   103.340366
# 23                                   103.066608
# 24                                   102.765391
# 25                                   102.560229
# 26                                   102.431813
# 27                                   102.306807
# 28                                   102.090111
# 29                                    101.91524
# 30                                   102.183947
# 31                                   102.443875
# 32                                   102.554257
# 33                                   102.565806
# 34                                   102.535769
# 35                                   102.328974
# 36                                   102.062501
# 37                                   102.178394
# 38                                   102.104673
# 39                                   102.075627
# 40                                   101.828584
# 41                                    101.85636
# 42                                   101.904172
# 43                                   102.028461
# 44                                   101.951321
# 45                                   101.878199
# 46                                   101.617126
# 47                                   101.365606
# 48                                   101.102696
# 49                                   100.950371
#
#    Scottsbluff Factory.KEPWARE.CLAR_FI1226/PLOT
# 0                  CLARIFIER MUD TO PONDS FLOW   \
# 1                                           GPM
# 2                                             0
# 3                                          1000
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                   347.204034
# 12                                    13.829021
# 13                                   230.906931
# 14                                   391.830073
# 15                                          NaN
# 16                                          NaN
# 17                                    340.18695
# 18                                   342.755847
# 19                                   342.667976
# 20                                    341.45995
# 21                                   338.723056
# 22                                   343.409027
# 23                                   343.353629
# 24                                   343.724788
# 25                                    341.88729
# 26                                   344.998187
# 27                                     344.1074
# 28                                   341.365039
# 29                                   337.191895
# 30                                   334.658975
# 31                                   338.588042
# 32                                   336.416601
# 33                                   337.339132
# 34                                   342.665153
# 35                                   340.293935
# 36                                   326.411595
# 37                                   340.052439
# 38                                    343.34224
# 39                                   344.984174
# 40                                   340.630101
# 41                                   341.340848
# 42                                   339.601105
# 43                                   333.096893
# 44                                   342.049139
# 45                                   339.264605
# 46                                   340.675804
# 47                                   335.584216
# 48                                   341.364314
# 49                                   339.890131
#
#    Scottsbluff Factory.KEPWARE.CLAR_LI1221/PLOT
# 0                          CONSTANT LEVEL TANK   \
# 1                                             %
# 2                                             0
# 3                                           100
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                    95.104078
# 12                                    30.652749
# 13                                    -0.336538
# 14                                   105.133099
# 15                                          NaN
# 16                                          NaN
# 17                                   105.101525
# 18                                   105.101822
# 19                                   105.102386
# 20                                   105.102386
# 21                                    105.09896
# 22                                   105.092525
# 23                                    105.09287
# 24                                   105.092991
# 25                                   105.091804
# 26                                   105.090146
# 27                                   105.089554
# 28                                   105.089795
# 29                                    105.09074
# 30                                   105.089554
# 31                                   105.089554
# 32                                   105.089554
# 33                                   105.089551
# 34                                   105.088033
# 35                                   105.088211
# 36                                   105.088041
# 37                                    105.08502
# 38                                   105.079479
# 39                                   105.078842
# 40                                   105.078842
# 41                                   105.078062
# 42                                   105.076917
# 43                                   105.077921
# 44                                   105.076706
# 45                                   105.075941
# 46                                   105.076043
# 47                                   105.076705
# 48                                   105.075238
# 49                                    105.07457
#
#    Scottsbluff Factory.KEPWARE.CLAR_LI1222/PLOT
# 0                                WET PIT LEVEL
# 1                                             %
# 2                                             0
# 3                                           100
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                    30.296211
# 12                                    22.892572
# 13                                     0.067819
# 14                                   104.980392
# 15                                          NaN
# 16                                          NaN
# 17                                     7.749336
# 18                                     7.641059
# 19                                     7.608085
# 20                                     7.684888
# 21                                     7.766588
# 22                                       7.7805
# 23                                     7.534729
# 24                                     7.505854
# 25                                     7.610041
# 26                                     7.665678
# 27                                     7.865617
# 28                                     7.699666
# 29                                     7.179772
# 30                                     7.287208
# 31                                     7.278751
# 32                                     7.252113
# 33                                     7.348899
# 34                                     7.260147
# 35                                     7.229403
# 36                                     7.232878
# 37                                     7.006187
# 38                                     7.202139
# 39                                     7.172994
# 40                                     7.157401
# 41                                     7.252487
# 42                                     7.229568
# 43                                     7.139142
# 44                                     7.402645
# 45                                     7.339739
# 46                                     7.574373
# 47                                     7.562152
# 48                                     7.472396
# 49                                     7.344537

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2'], axis=1)

# %%
df.head(20)
# Out:
#                Tag Name
# 0                 Descr  \
# 1                 Units
# 2              Plot Min
# 3              Plot Max
# 4            Filter Min
# 5            Filter Max
# 6              Excl Row
# 7           Interpolate
# 8              Decimals
# 9            Time Delay
# 10                Count
# 11                  Avg
# 12                   SD
# 13                  Min
# 14                  Max
# 15       Test Data/Calc
# 16                 6862
# 17  2022-11-01 00:00:00
# 18  2022-11-01 00:15:00
# 19  2022-11-01 00:30:00
#
#    Scottsbluff Factory.KEPWARE.Program:A12_DR_MEAS.WT1201.Val/PLOT
# 0                                    Dirty Beet Scale               \
# 1                                                T/hr
# 2                                                   0
# 3                                                 500
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                             TimeAvg
# 8                                                   2
# 9                                                   0
# 10                                               6862
# 11                                         298.727298
# 12                                         110.935243
# 13                                          -1.792251
# 14                                         575.521113
# 15                                                NaN
# 16                                                NaN
# 17                                         207.046703
# 18                                         201.440789
# 19                                         201.851792
#
#    Scottsbluff Factory.KEPWARE.FT1205/PLOT
# 0                         Flume Water Flow  \
# 1                                      GPM
# 2                                        0
# 3                                     5000
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                  TimeAvg
# 8                                        2
# 9                                        0
# 10                                    6862
# 11                             2005.754784
# 12                              777.016837
# 13                                    T/hr
# 14                             5570.462117
# 15                                     NaN
# 16                                     NaN
# 17                             1523.082898
# 18                              1521.41544
# 19                             1518.747017
#
#    Scottsbluff Factory.KEPWARE.FT1206/PLOT
# 0           Flume Water Recirculation Flow  \
# 1                                      GPM
# 2                                        0
# 3                                     5000
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                  TimeAvg
# 8                                        2
# 9                                        0
# 10                                    6862
# 11                             3342.655744
# 12                             1018.475668
# 13                                3.017314
# 14                             6886.899051
# 15                                     NaN
# 16                                     NaN
# 17                             4089.951859
# 18                             4013.366442
# 19                             4084.815351
#
#    Scottsbluff Factory.KEPWARE.Program:A12_JWRT_MEAS.PT1201.Val/PLOT
# 0                                       JWRT Pressure                 \
# 1                                                PSIG
# 2                                                   0
# 3                                                 150
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                             TimeAvg
# 8                                                   2
# 9                                                   0
# 10                                               6862
# 11                                          68.095628
# 12                                          19.181275
# 13                                          -0.922115
# 14                                         155.459335
# 15                                                NaN
# 16                                                NaN
# 17                                          71.869034
# 18                                          71.439815
# 19                                          71.567319
#
#    Scottsbluff Factory.KEPWARE.CLAR_LI1225/PLOT
# 0                              CLARIFIER LEVEL   \
# 1                                             %
# 2                                             0
# 3                                           100
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                    96.673845
# 12                                     15.61532
# 13                                       0.2783
# 14                                   105.124634
# 15                                          NaN
# 16                                          NaN
# 17                                   102.791712
# 18                                   103.485491
# 19                                   103.622652
#
#    Scottsbluff Factory.KEPWARE.CLAR_FI1226/PLOT
# 0                  CLARIFIER MUD TO PONDS FLOW   \
# 1                                           GPM
# 2                                             0
# 3                                          1000
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                   347.204034
# 12                                    13.829021
# 13                                   230.906931
# 14                                   391.830073
# 15                                          NaN
# 16                                          NaN
# 17                                    340.18695
# 18                                   342.755847
# 19                                   342.667976
#
#    Scottsbluff Factory.KEPWARE.CLAR_LI1221/PLOT
# 0                          CONSTANT LEVEL TANK   \
# 1                                             %
# 2                                             0
# 3                                           100
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                    95.104078
# 12                                    30.652749
# 13                                    -0.336538
# 14                                   105.133099
# 15                                          NaN
# 16                                          NaN
# 17                                   105.101525
# 18                                   105.101822
# 19                                   105.102386
#
#    Scottsbluff Factory.KEPWARE.CLAR_LI1222/PLOT
# 0                                WET PIT LEVEL
# 1                                             %
# 2                                             0
# 3                                           100
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                       TimeAvg
# 8                                             2
# 9                                             0
# 10                                         6862
# 11                                    30.296211
# 12                                    22.892572
# 13                                     0.067819
# 14                                   104.980392
# 15                                          NaN
# 16                                          NaN
# 17                                     7.749336
# 18                                     7.641059
# 19                                     7.608085

# %%
df.columns = ['Time', 'Dirty_Beet_Scale', 'Flume_Water_Scale', 'Flume Water Recirculation_Flow', 'JWRT_Pressure', 'Clarifier_Level', 'Clarifier_Mud_2_Ponds_Flow', 'Constant_Level_Tank', 'Wet_Pit_Level']

# %%
df.head(20)
# Out:
#                    Time  Dirty_Beet_Scale Flume_Water_Scale
# 0                 Descr  Dirty Beet Scale  Flume Water Flow  \
# 1                 Units              T/hr               GPM
# 2              Plot Min                 0                 0
# 3              Plot Max               500              5000
# 4            Filter Min               NaN               NaN
# 5            Filter Max               NaN               NaN
# 6              Excl Row               NaN               NaN
# 7           Interpolate           TimeAvg           TimeAvg
# 8              Decimals                 2                 2
# 9            Time Delay                 0                 0
# 10                Count              6862              6862
# 11                  Avg        298.727298       2005.754784
# 12                   SD        110.935243        777.016837
# 13                  Min         -1.792251              T/hr
# 14                  Max        575.521113       5570.462117
# 15       Test Data/Calc               NaN               NaN
# 16                 6862               NaN               NaN
# 17  2022-11-01 00:00:00        207.046703       1523.082898
# 18  2022-11-01 00:15:00        201.440789        1521.41544
# 19  2022-11-01 00:30:00        201.851792       1518.747017
#
#     Flume Water Recirculation_Flow  JWRT_Pressure   Clarifier_Level
# 0   Flume Water Recirculation Flow  JWRT Pressure  CLARIFIER LEVEL   \
# 1                              GPM           PSIG                 %
# 2                                0              0                 0
# 3                             5000            150               100
# 4                              NaN            NaN               NaN
# 5                              NaN            NaN               NaN
# 6                              NaN            NaN               NaN
# 7                          TimeAvg        TimeAvg           TimeAvg
# 8                                2              2                 2
# 9                                0              0                 0
# 10                            6862           6862              6862
# 11                     3342.655744      68.095628         96.673845
# 12                     1018.475668      19.181275          15.61532
# 13                        3.017314      -0.922115            0.2783
# 14                     6886.899051     155.459335        105.124634
# 15                             NaN            NaN               NaN
# 16                             NaN            NaN               NaN
# 17                     4089.951859      71.869034        102.791712
# 18                     4013.366442      71.439815        103.485491
# 19                     4084.815351      71.567319        103.622652
#
#       Clarifier_Mud_2_Ponds_Flow   Constant_Level_Tank   Wet_Pit_Level
# 0   CLARIFIER MUD TO PONDS FLOW   CONSTANT LEVEL TANK   WET PIT LEVEL
# 1                            GPM                     %               %
# 2                              0                     0               0
# 3                           1000                   100             100
# 4                            NaN                   NaN             NaN
# 5                            NaN                   NaN             NaN
# 6                            NaN                   NaN             NaN
# 7                        TimeAvg               TimeAvg         TimeAvg
# 8                              2                     2               2
# 9                              0                     0               0
# 10                          6862                  6862            6862
# 11                    347.204034             95.104078       30.296211
# 12                     13.829021             30.652749       22.892572
# 13                    230.906931             -0.336538        0.067819
# 14                    391.830073            105.133099      104.980392
# 15                           NaN                   NaN             NaN
# 16                           NaN                   NaN             NaN
# 17                     340.18695            105.101525        7.749336
# 18                    342.755847            105.101822        7.641059
# 19                    342.667976            105.102386        7.608085

# %%
df1 = df.iloc[17:]
df1.head(20)
# Out:
#                    Time Dirty_Beet_Scale Flume_Water_Scale
# 17  2022-11-01 00:00:00       207.046703       1523.082898  \
# 18  2022-11-01 00:15:00       201.440789        1521.41544
# 19  2022-11-01 00:30:00       201.851792       1518.747017
# 20  2022-11-01 00:45:00       194.654034       1499.718798
# 21  2022-11-01 01:00:00        197.31388       1413.060983
# 22  2022-11-01 01:15:00       195.138613       1417.734382
# 23  2022-11-01 01:30:00       225.422243       1436.529496
# 24  2022-11-01 01:45:00       264.607173       1416.030815
# 25  2022-11-01 02:00:00       264.242898       1434.679602
# 26  2022-11-01 02:15:00       252.922698       1419.331633
# 27  2022-11-01 02:30:00        202.46005       1430.888168
# 28  2022-11-01 02:45:00       239.144716       1402.535359
# 29  2022-11-01 03:00:00       244.450888       1418.433495
# 30  2022-11-01 03:15:00       250.077046       1423.214045
# 31  2022-11-01 03:30:00        245.56797       1481.740051
# 32  2022-11-01 03:45:00       244.472725       1571.077854
# 33  2022-11-01 04:00:00       247.747752       1742.549014
# 34  2022-11-01 04:15:00       247.475404       1723.661979
# 35  2022-11-01 04:30:00       248.737922       1708.205778
# 36  2022-11-01 04:45:00       243.128553       1670.863439
#
#    Flume Water Recirculation_Flow JWRT_Pressure Clarifier_Level
# 17                    4089.951859     71.869034      102.791712  \
# 18                    4013.366442     71.439815      103.485491
# 19                    4084.815351     71.567319      103.622652
# 20                    4110.266287     71.479829       103.56744
# 21                     4094.27441       71.4033      103.452863
# 22                      4126.0549     71.512524      103.340366
# 23                    4120.153496     71.398357      103.066608
# 24                    4090.206369     71.353967      102.765391
# 25                    4098.173422     71.423856      102.560229
# 26                    4082.664848     71.400347      102.431813
# 27                    4038.808912     71.284425      102.306807
# 28                    4076.126838      71.23965      102.090111
# 29                    4083.184587     71.114203       101.91524
# 30                    4090.092851     71.119309      102.183947
# 31                    4098.558991     71.168445      102.443875
# 32                    4087.628348      71.26267      102.554257
# 33                    4090.962053     71.357733      102.565806
# 34                    4066.751806     71.254236      102.535769
# 35                    4067.597289     70.985951      102.328974
# 36                    4105.531632      70.94944      102.062501
#
#    Clarifier_Mud_2_Ponds_Flow Constant_Level_Tank Wet_Pit_Level
# 17                  340.18695          105.101525      7.749336
# 18                 342.755847          105.101822      7.641059
# 19                 342.667976          105.102386      7.608085
# 20                  341.45995          105.102386      7.684888
# 21                 338.723056           105.09896      7.766588
# 22                 343.409027          105.092525        7.7805
# 23                 343.353629           105.09287      7.534729
# 24                 343.724788          105.092991      7.505854
# 25                  341.88729          105.091804      7.610041
# 26                 344.998187          105.090146      7.665678
# 27                   344.1074          105.089554      7.865617
# 28                 341.365039          105.089795      7.699666
# 29                 337.191895           105.09074      7.179772
# 30                 334.658975          105.089554      7.287208
# 31                 338.588042          105.089554      7.278751
# 32                 336.416601          105.089554      7.252113
# 33                 337.339132          105.089551      7.348899
# 34                 342.665153          105.088033      7.260147
# 35                 340.293935          105.088211      7.229403
# 36                 326.411595          105.088041      7.232878

# %%
df2 =df1.copy()

# %%
df2.head()
# Out:
#                    Time Dirty_Beet_Scale Flume_Water_Scale
# 17  2022-11-01 00:00:00       207.046703       1523.082898  \
# 18  2022-11-01 00:15:00       201.440789        1521.41544
# 19  2022-11-01 00:30:00       201.851792       1518.747017
# 20  2022-11-01 00:45:00       194.654034       1499.718798
# 21  2022-11-01 01:00:00        197.31388       1413.060983
#
#    Flume Water Recirculation_Flow JWRT_Pressure Clarifier_Level
# 17                    4089.951859     71.869034      102.791712  \
# 18                    4013.366442     71.439815      103.485491
# 19                    4084.815351     71.567319      103.622652
# 20                    4110.266287     71.479829       103.56744
# 21                     4094.27441       71.4033      103.452863
#
#    Clarifier_Mud_2_Ponds_Flow Constant_Level_Tank Wet_Pit_Level
# 17                  340.18695          105.101525      7.749336
# 18                 342.755847          105.101822      7.641059
# 19                 342.667976          105.102386      7.608085
# 20                  341.45995          105.102386      7.684888
# 21                 338.723056           105.09896      7.766588

# %%
df2.Time.unique()
# Out:
# array([datetime.datetime(2022, 11, 1, 0, 0),
#        datetime.datetime(2022, 11, 1, 0, 15),
#        datetime.datetime(2022, 11, 1, 0, 30), ...,
#        datetime.datetime(2023, 1, 11, 10, 45),
#        datetime.datetime(2023, 1, 11, 11, 0),
#        datetime.datetime(2023, 1, 11, 11, 15)], dtype=object)

# %%
df2['Time'] = pd.to_datetime(df2['Time'])
df2['Time']
# Out:
# 17     2022-11-01 00:00:00
# 18     2022-11-01 00:15:00
# 19     2022-11-01 00:30:00
# 20     2022-11-01 00:45:00
# 21     2022-11-01 01:00:00
#                ...
# 6874   2023-01-11 10:15:00
# 6875   2023-01-11 10:30:00
# 6876   2023-01-11 10:45:00
# 6877   2023-01-11 11:00:00
# 6878   2023-01-11 11:15:00
# Name: Time, Length: 6862, dtype: datetime64[ns]

# %%
df2['Time'].min(), df2['Time'].max()
# Out:
# (datetime.datetime(2022, 11, 1, 0, 0), datetime.datetime(2023, 1, 11, 11, 15))

# %%
# df2['Time'].max() - df2['Time'].min()
# Out:
# datetime.timedelta(days=71, seconds=40500)

# %%
df2.groupby(df2['Time'].dt.month)['Clarifier_Level'].mean()
# Out:
# Time
# 1     101.511969
# 11    100.515458
# 12     91.320687
# Name: Clarifier_Level, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(figsize=(12, 4))

df2.groupby(df2['Time'].dt.month)['Clarifier_Level'].mean().plot(kind='bar', rot=0, ax=axs)

plt.xlabel('Hour of the Day')
plt.ylabel('Clarifier Level %')
# Out:
# Text(0, 0.5, 'Clarifier Level %')

# %%
def plot_df(df2, x, y, title="", xlabel='Time', ylabel='Clarifier_Level', dpi=100):
    plt.figure(figsize=(15,4), dpi=dpi)
    plt.plot(x, y, color='blue')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()


plot_df(df2, x=df2['Time'], y=df2['Clarifier_Level'], title='Trend and Seasonality')

# %%
def plot_df(df2, x, y, title="", xlabel='Time', ylabel='Wet_Pit_Level', dpi=100):
    plt.figure(figsize=(15,4), dpi=dpi)
    plt.plot(x, y, color='orange')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()


plot_df(df2, x=df2['Time'], y=df2['Wet_Pit_Level'], title='Trend and Seasonality')

# %%
df2_columns = df.columns.copy()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

#Multiplicative Decomposition
multiplicative_decomposition = seasonal_decompose(df2['Clarifier_Level'], model='multiplicative', period=30)

#Additive Decomposition
additive_decomposition = seasonal_decompose(df2['Clarifier_Level'], model='additive', period=30)

#Plot
plt.rcParams.update({'figure.figsize':(16, 12)})
multiplicative_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize = 16)
plt.tight_layout(rect = [0, 0.03, 1, 0.95])

additive_decomposition.plot().suptitle('Additive Decomposition', fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()

# %%
series = df2.loc[:, 'Clarifier_Level'].values

# %%
#ADF Test - Augmented Dickey Fuller Test

from statsmodels.tsa.stattools import adfuller
result = adfuller(series, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critical Values:')
    print(f'    {key}, {value}')
# Out:
# ADF Statistic: -6.642256235169803
# n_lags: 5.373174738179152e-09
# p-value: 5.373174738179152e-09
# Critical Values:
#     1%, -3.431307657594668
# Critical Values:
#     5%, -2.8619632060722413
# Critical Values:
#     10%, -2.5669952688059707

# %%
#Test for Seasonality
from pandas.plotting import autocorrelation_plot

#Draw Plot
plt.rcParams.update({'figure.figsize':(10, 6), 'figure.dpi':80})
autocorrelation_plot(df2['Clarifier_Level']).tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 6
#       4 #Draw Plot
#       5 plt.rcParams.update({'figure.figsize':(10, 6), 'figure.dpi':80})
# ----> 6 autocorrelation_plot(df2['Clarifier_Level']).tolist()
#
# AttributeError: 'Axes' object has no attribute 'tolist'

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Draw Plot
fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
plot_acf(df2['Clarifier_Level'].tolist(), lags=50, ax=axes[0])
plot_pacf(df2['Clarifier_Level'].tolist(), lags=50, ax=axes[1])

# %%
#Lag Plot

from pandas.plotting import lag_plot
plt.rcParams.update({'ytick.left' : False, 'axes.titlepad':10})

# Plot
fig, axes = plt.subplots(1, 4, figsize=(10,3), sharex=True, sharey=True, dpi=100)
for i, ax in enumerate(axes.flatten()[:4]):
    lag_plot(df2['Clarifier_Level'], lag=i+1, ax=ax, c='firebrick')
    ax.set_title('Lag ' + str(i+1))

fig.suptitle('Lag Plots of Clarifier Level', y=1.05)
plt.show()

# %%
from statsmodels.tsa.stattools import grangercausalitytests
grangercausalitytests(df2[['Time']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=6860, df_num=1
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 from statsmodels.tsa.stattools import grangercausalitytests
# ----> 2 grangercausalitytests(df2[['Time']], maxlag=2)
#
# File ~/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:1615, in grangercausalitytests(x, maxlag, addconst, verbose)
#    1611 # F test that all lag coefficients of exog are zero
#    1612 rconstr = np.column_stack(
#    1613     (np.zeros((mxlg, mxlg)), np.eye(mxlg, mxlg), np.zeros((mxlg, 1)))
#    1614 )
# -> 1615 ftres = res2djoint.f_test(rconstr)
#    1616 if verbose:
#    1617     print(
#    1618         "parameter F test:         F=%-8.4f, p=%-8.4f, df_denom=%d,"
#    1619         " df_num=%d"
#    1620         % (ftres.fvalue, ftres.pvalue, ftres.df_denom, ftres.df_num)
#    1621     )
#
# File ~/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/statsmodels/base/model.py:1782, in LikelihoodModelResults.f_test(self, r_matrix, cov_p, invcov)
#    1689 def f_test(self, r_matrix, cov_p=None, invcov=None):
#    1690     """
#    1691     Compute the F-test for a joint linear hypothesis.
#    1692
#    (...)
#    1780     <F test: F=array([[ 144.17976065]]), p=6.322026217355609e-08, df_denom=9, df_num=3>
#    1781     """
# -> 1782     res = self.wald_test(r_matrix, cov_p=cov_p, invcov=invcov, use_f=True, scalar=True)
#    1783     return res
#
# File ~/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/statsmodels/base/model.py:1858, in LikelihoodModelResults.wald_test(self, r_matrix, cov_p, invcov, use_f, df_constraints, scalar)
#    1856 names = self.model.data.cov_names
#    1857 params = self.params.ravel()
# -> 1858 LC = DesignInfo(names).linear_constraint(r_matrix)
#    1859 r_matrix, q_matrix = LC.coefs, LC.constants
#    1861 if (self.normalized_cov_params is None and cov_p is None and
#    1862         invcov is None and not hasattr(self, 'cov_params_default')):
#
# File ~/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/patsy/design_info.py:536, in DesignInfo.linear_constraint(self, constraint_likes)
#     487 def linear_constraint(self, constraint_likes):
#     488     """Construct a linear constraint in matrix form from a (possibly
#     489     symbolic) description.
#     490
#    (...)
#     534       di.linear_constraint("x1 = x2 = 3")
#     535     """
# --> 536     return linear_constraint(constraint_likes, self.column_names)
#
# File ~/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/patsy/constraint.py:419, in linear_constraint(constraint_like, variable_names)
#     417 # assume a raw ndarray
#     418 coefs = np.asarray(constraint_like, dtype=float)
# --> 419 return LinearConstraint(variable_names, coefs)
#
# File ~/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/patsy/constraint.py:60, in LinearConstraint.__init__(self, variable_names, coefs, constants)
#      58     raise ValueError("constants is not (convertible to) a column matrix")
#      59 if self.coefs.ndim != 2 or self.coefs.shape[1] != len(variable_names):
# ---> 60     raise ValueError("wrong shape for coefs")
#      61 if self.coefs.shape[0] == 0:
#      62     raise ValueError("must have at least one row in constraint matrix")
#
# ValueError: wrong shape for coefs

# %%
import seaborn as sns
corr_df =  pd.DataFrame(columns=df2_columns[1:])
corr_matrix = corr_df.corr()

sns.heatmap(corr_matrix, cmap='PuOr')
# Out:
# /Users/saikiranpennam/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /Users/saikiranpennam/PycharmProjects/sugarbeet_analysis/venv/lib/python3.9/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <Axes: >
